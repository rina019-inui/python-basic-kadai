# %%
tax = 1.1

def total():
  price1 = 100
  price2 = 200
  total =price1 + price2
  return total

print(total() * tax)
# Out:
# 330.0

# %%
price1 = 100
price2 = 200

def total():
    tax = 1.1
    total =(price1 + price2) * tax
    return total

print (total())
# Out:
# 363.00000000000006

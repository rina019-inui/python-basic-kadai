# %%
class Human:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def check_adult(self):
      if  self.age >= 20:
        print(f"{self.name}は大人です。")
      else:
        print(f"{self.name}は大人ではありません。")

person_1 = Human("太郎", 25)
person_2 = Human("花子", 17)
person_3 = Human("健太", 30)

persons = [person_1,person_2,person_3]

for person in persons:
  person.check_adult()
# Out:
# 太郎は大人です。
# 花子は大人ではありません。
# 健太は大人です。

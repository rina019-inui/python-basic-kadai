# %%
array = ["月曜日", "火曜日", "水曜日", "木曜日", "金曜日","土曜日","日曜日"]
weather = ["晴れ", "雨", "晴れ", "晴れ", "曇り","曇りのち雨","雷雨"]

wednesday_weather = weather[array.index("水曜日")]
print("水曜日の天気予報", wednesday_weather,"です")

dictionary = {"月曜日":"晴れ",
              "火曜日":"雨",
              "水曜日":"晴れ",
              "木曜日":"晴れ",
              "金曜日":"曇り",
              "土曜日":"曇りのち雨",
              "日曜日":"雷雨"}
wednesday_weather = dictionary["水曜日"]
print("水曜日の天気予報",wednesday_weather,"です")
# Out:
# 水曜日の天気予報 晴れ です
# 水曜日の天気予報 晴れ です
